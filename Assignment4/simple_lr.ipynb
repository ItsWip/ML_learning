# %%
import pandas as pd
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

import matplotlib.pyplot as plt

# %%
salary_df= pd.read_csv("datasets/salary_data.csv")

# %%
salary_df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
salary_df.shape
# Out:
# (30, 2)

# %%
x=salary_df[["YearsExperience"]]
y=salary_df["Salary"]

# %%
x.head(), y.head()
# Out:
# (   YearsExperience
#  0              1.1
#  1              1.3
#  2              1.5
#  3              2.0
#  4              2.2,
#  0    39343.0
#  1    46205.0
#  2    37731.0
#  3    43525.0
#  4    39891.0
#  Name: Salary, dtype: float64)

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.3, random_state=792725)

# %%
x_train.shape, y_test.shape
# Out:
# ((21, 1), (9,))

# %% [markdown]
# ## Building Linear Regression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= lr.predict(x_test)
y_pred
# Out:
# array([67976.97979665, 55373.7108358 , 52465.26415253, 62160.0864301 ,
#        53434.74638028, 35014.58405289, 36953.5485084 , 63129.56865786,
#        63129.56865786])

# %% [markdown]
# ## Evaluation Metrics
# MSE
# MAE
# RMSE
# MAPE
# r2score

# %%
plt.scatter(x_test,y_test, color='red')
plt.plot(x_test,lr.predict(x_test), color="blue")

# %%
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'R² Score: {r2:.4f}')
print(f'Mean Squared Error: {mse:.4f}')
# Out:
# R² Score: 0.3324
# Mean Squared Error: 34210980.8562
